# %%
# using pandas to read excel file

import pandas as pd
# print(dir(pd))

# %%
# if you get import error while reading excel file-> make sure to pip install xlrd

df=pd.read_excel('C:/Users/Admin/Desktop/Data-Pandas/PandasExcel/excel/movies.xls',engine='xlrd')

# %%
# print(dir(df)) # different methods available with pandas df

# %%
df.shape # rows * columns
# Out:
# (1338, 25)

# %%
len(df)
# Out:
# 1338

# %%
df.size # size tells us the total number of data points in the dataframe.
# Out:
# 33450

# %%
df.columns
# Out:
# Index(['Title', 'Year', 'Genres', 'Language', 'Country', 'Content Rating',
#        'Duration', 'Aspect Ratio', 'Budget', 'Gross Earnings', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3', 'Facebook Likes - Director',
#        'Facebook Likes - Actor 1', 'Facebook Likes - Actor 2',
#        'Facebook Likes - Actor 3', 'Facebook Likes - cast Total',
#        'Facebook likes - Movie', 'Facenumber in posters', 'User Votes',
#        'Reviews by Users', 'Reviews by Crtiics', 'IMDB Score'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Title                        1338 non-null   object
#  1   Year                         1338 non-null   int64
#  2   Genres                       1338 non-null   object
#  3   Language                     1334 non-null   object
#  4   Country                      1338 non-null   object
#  5   Content Rating               1316 non-null   object
#  6   Duration                     1338 non-null   int64
#  7   Aspect Ratio                 1308 non-null   float64
#  8   Budget                       1281 non-null   float64
#  9   Gross Earnings               1086 non-null   float64
#  10  Director                     1338 non-null   object
#  11  Actor 1                      1338 non-null   object
#  12  Actor 2                      1338 non-null   object
# ...

# %%
df
# Out:
#                                                   Title  Year  \
# 0     Intolerance: Love's Struggle Throughout the Ages   1916
# 1                       Over the Hill to the Poorhouse   1920
# 2                                       The Big Parade   1925
# 3                                           Metropolis   1927
# 4                                        Pandora's Box   1929
# ...                                                 ...   ...
# 1333                                  Twin Falls Idaho   1999
# 1334                     Universal Soldier: The Return   1999
# 1335                                     Varsity Blues   1999
# 1336                                    Wild Wild West   1999
# 1337                                    Wing Commander   1999
#
#                             Genres Language  Country Content Rating  Duration  \
# 0                Drama|History|War      NaN      USA      Not Rated       123
# ...

# %%
df.describe(include='all') # statistical info about my dataframe
# Out:
#              Title         Year Genres Language Country Content Rating  \
# count         1338  1338.000000   1338     1334    1338           1316
# unique        1310          NaN    430       15      28             13
# top     Halloween           NaN  Drama  English     USA              R
# freq             3          NaN     62     1290    1073            650
# mean           NaN  1987.289985    NaN      NaN     NaN            NaN
# std            NaN    14.124870    NaN      NaN     NaN            NaN
# min            NaN  1916.000000    NaN      NaN     NaN            NaN
# 25%            NaN  1982.000000    NaN      NaN     NaN            NaN
# 50%            NaN  1993.000000    NaN      NaN     NaN            NaN
# 75%            NaN  1997.000000    NaN      NaN     NaN            NaN
# max            NaN  1999.000000    NaN      NaN     NaN            NaN
#
#            Duration  Aspect Ratio        Budget  Gross Earnings  ...  \
# ...

# %%
df.isnull().any() # checking if the df contains missing values
# Out:
# Title                          False
# Year                           False
# Genres                         False
# Language                        True
# Country                        False
# Content Rating                  True
# Duration                       False
# Aspect Ratio                    True
# Budget                          True
# Gross Earnings                  True
# Director                       False
# Actor 1                        False
# Actor 2                        False
# Actor 3                         True
# Facebook Likes - Director      False
# Facebook Likes - Actor 1       False
# Facebook Likes - Actor 2       False
# Facebook Likes - Actor 3        True
# Facebook Likes - cast Total    False
# Facebook likes - Movie         False
# Facenumber in posters          False
# User Votes                     False
# Reviews by Users               False
# Reviews by Crtiics              True
# IMDB Score                     False
# dtype: bool

# %%
df.isnull().sum() # returns the number of missing values for each column
# Out:
# Title                            0
# Year                             0
# Genres                           0
# Language                         4
# Country                          0
# Content Rating                  22
# Duration                         0
# Aspect Ratio                    30
# Budget                          57
# Gross Earnings                 252
# Director                         0
# Actor 1                          0
# Actor 2                          0
# Actor 3                          2
# Facebook Likes - Director        0
# Facebook Likes - Actor 1         0
# Facebook Likes - Actor 2         0
# Facebook Likes - Actor 3         2
# Facebook Likes - cast Total      0
# Facebook likes - Movie           0
# Facenumber in posters            0
# User Votes                       0
# Reviews by Users                 0
# Reviews by Crtiics               3
# IMDB Score                       0
# dtype: int64

# %%
df.head(10) # returns first 5 records
# Out:
#                                                Title  Year  \
# 0  Intolerance: Love's Struggle Throughout the Ages   1916
# 1                    Over the Hill to the Poorhouse   1920
# 2                                    The Big Parade   1925
# 3                                        Metropolis   1927
# 4                                     Pandora's Box   1929
# 5                               The Broadway Melody   1929
# 6                                     Hell's Angels   1930
# 7                                A Farewell to Arms   1932
# 8                                       42nd Street   1933
# 9                                She Done Him Wrong   1933
#
#                                  Genres Language  Country Content Rating  \
# 0                     Drama|History|War      NaN      USA      Not Rated
# 1                           Crime|Drama      NaN      USA            NaN
# 2                     Drama|Romance|War      NaN      USA      Not Rated
# ...

# %%
df.tail()
# Out:
#                                Title  Year                        Genres  \
# 1333               Twin Falls Idaho   1999                         Drama
# 1334  Universal Soldier: The Return   1999                 Action|Sci-Fi
# 1335                  Varsity Blues   1999    Comedy|Drama|Romance|Sport
# 1336                 Wild Wild West   1999  Action|Comedy|Sci-Fi|Western
# 1337                 Wing Commander   1999       Action|Adventure|Sci-Fi
#
#      Language Country Content Rating  Duration  Aspect Ratio       Budget  \
# 1333  English     USA              R       111          1.85     500000.0
# 1334  English     USA              R        83          1.85   24000000.0
# 1335  English     USA              R       106          1.85   16000000.0
# 1336  English     USA          PG-13       106          1.85  170000000.0
# 1337  English     USA          PG-13       100          2.35   30000000.0
#
#       Gross Earnings  ... Facebook Likes - Actor 1 Facebook Likes - Actor 2  \
# ...

# %%
df[['Title','Year']]  # fetching specific columns
# Out:
#                                                   Title  Year
# 0     Intolerance: Love's Struggle Throughout the Ages   1916
# 1                       Over the Hill to the Poorhouse   1920
# 2                                       The Big Parade   1925
# 3                                           Metropolis   1927
# 4                                        Pandora's Box   1929
# ...                                                 ...   ...
# 1333                                  Twin Falls Idaho   1999
# 1334                     Universal Soldier: The Return   1999
# 1335                                     Varsity Blues   1999
# 1336                                    Wild Wild West   1999
# 1337                                    Wing Commander   1999
#
# [1338 rows x 2 columns]

# %%
# df.dropna(inplace=True) # this will allow to drop the missing values from the df

# %%
# df.fillna(method='') # method to fill missing values

# %%
# df.isnull().any() # no more missing values as they are dropped

# %%
# df.dtypes

# %%
df.reset_index(inplace=True)

# %%
df=df.drop(columns='index',axis=1)

# %%
df.loc[0,'Title'] # the first parameter will be integer rep row , second parameter will be 'text' rep column
# Out:
# "Intolerance: Love's Struggle Throughout the Ages\xa0"

# %%
df[0:5]
# Out:
#                                                Title  Year  \
# 0  Intolerance: Love's Struggle Throughout the Ages   1916
# 1                    Over the Hill to the Poorhouse   1920
# 2                                    The Big Parade   1925
# 3                                        Metropolis   1927
# 4                                     Pandora's Box   1929
#
#                 Genres Language  Country Content Rating  Duration  \
# 0    Drama|History|War      NaN      USA      Not Rated       123
# 1          Crime|Drama      NaN      USA            NaN       110
# 2    Drama|Romance|War      NaN      USA      Not Rated       151
# 3         Drama|Sci-Fi   German  Germany      Not Rated       145
# 4  Crime|Drama|Romance   German  Germany      Not Rated       110
#
#    Aspect Ratio     Budget  Gross Earnings  ... Facebook Likes - Actor 1  \
# 0          1.33   385907.0             NaN  ...                      436
# ...

# %%
df.iloc[0,0] # the first param refers to row indexing , second param refers to column indexing
# Out:
# "Intolerance: Love's Struggle Throughout the Ages\xa0"

# %%
df.iloc[0,1]=1917

# %%
df.columns
# Out:
# Index(['Title', 'Year', 'Genres', 'Language', 'Country', 'Content Rating',
#        'Duration', 'Aspect Ratio', 'Budget', 'Gross Earnings', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3', 'Facebook Likes - Director',
#        'Facebook Likes - Actor 1', 'Facebook Likes - Actor 2',
#        'Facebook Likes - Actor 3', 'Facebook Likes - cast Total',
#        'Facebook likes - Movie', 'Facenumber in posters', 'User Votes',
#        'Reviews by Users', 'Reviews by Crtiics', 'IMDB Score'],
#       dtype='object')

# %%
# df.query('Year >1915 & Genres=="Crime|Drama"')

# %%
df[(df['Year']>1915) & (df['Genres']=="Crime|Drama")][['Country','Content Rating']]

# remeber the above two syntax for performing conditional checks
# Out:
#       Country Content Rating
# 1         USA            NaN
# 41        USA       Approved
# 68        USA      Not Rated
# 89        USA      Not Rated
# 178       USA              R
# 192       USA              R
# 209       USA              R
# 319       USA              R
# 358       USA              R
# 362       USA          PG-13
# 385     Italy              R
# 443       USA              R
# 487       USA              R
# 576       USA              R
# 584       USA              R
# 603       USA              R
# 629       USA              R
# 649       USA              R
# 723       USA              R
# 742       USA              R
# 754       USA            NaN
# 765        UK              R
# 811       USA              R
# 895       USA              R
# 1042      USA              R
# 1109      USA              R
# 1110  Germany              R
